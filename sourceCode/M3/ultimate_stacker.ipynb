# %% [markdown]
# # Compromises:
# ## Neural Network:
# - Can't do log-linking
# - ELU not supported

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import StackingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import train_test_split

from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.metrics import r2_score, accuracy_score, recall_score,precision_score, confusion_matrix

import pandas as pd
import numpy as np

# %%
# df = pd.read_csv(r"data\claims_train_scaled.csv")
df = pd.read_csv(r"../../data/claims_train_scaled.csv")
# df.drop("Area",axis=1,inplace=True)
# fuel_map = {'Regular': 0, 'Diesel': 1}
# df['VehGas'] = df['VehGas'].map(fuel_map)
# x = df.drop(columns=["ClaimNb","Region","VehBrand","VehGas"])
x = df.drop(columns=["ClaimNb"])
x = pd.get_dummies(x, columns=['Region','VehGas','VehBrand'], drop_first=True, dtype=float)

y = (df["ClaimNb"] > 0).astype(int)

x_train, x_val, y_train, y_val = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
estimators = [
    ('rf', RandomForestClassifier(random_state=42, criterion='log_loss', verbose=1, oob_score=False, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=False)),
    ('svr', make_pipeline(StandardScaler(),
                          LinearSVC(random_state=42, tol=1e-06, penalty='l2', loss='squared_hinge', C=0.75))),
    ('mlp', MLPClassifier(hidden_layer_sizes=(192,48,48), random_state=42, max_iter=30, batch_size=1000,learning_rate_init=0.001,activation='relu',verbose=True, early_stopping=True, tol=1e-6)),
    ('gbr', HistGradientBoostingClassifier(
                max_iter=1000,
                learning_rate=0.46, 
                max_depth=7,
                verbose=1,
                # categorical_features=["Region","VehBrand","VehGas"],
            )),
]

clf = StackingClassifier(
    estimators=estimators, final_estimator=LogisticRegression(), verbose=2, n_jobs=-1
)

clf.fit(x_train, y_train).score(x_val, y_val)
# Out:
# Binning 0.118 GB of training data: 0.796 s
# Binning 0.013 GB of validation data: 0.068 s
# Fitting gradient boosted rounds:
# Fit 21 trees in 3.820 s, (651 total leaves)
# Time spent computing histograms: 1.860s
# Time spent finding best splits:  0.011s
# Time spent applying splits:      0.152s
# Time spent predicting:           0.011s
# Iteration 1, loss = 0.20205585
# Validation score: 0.949864
# Iteration 2, loss = 0.19108276
# Validation score: 0.949864
# Iteration 3, loss = 0.18945410
# Validation score: 0.949864
# Iteration 4, loss = 0.18812497
# Validation score: 0.949864
# Iteration 5, loss = 0.18724372
# Validation score: 0.949748
# Iteration 6, loss = 0.18646428
# Validation score: 0.949864
# Iteration 7, loss = 0.18595205
# Validation score: 0.949817
# Iteration 8, loss = 0.18542457
# Validation score: 0.949841
# Iteration 9, loss = 0.18513000
# Validation score: 0.949794
# Iteration 10, loss = 0.18455226
# Validation score: 0.949817
# Iteration 11, loss = 0.18434998
# Validation score: 0.949771
# Iteration 12, loss = 0.18391429
# Validation score: 0.949771
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  7.1min finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# Binning 0.095 GB of training data: Binning 0.095 GB of training data: Binning 0.095 GB of training data: Binning 0.095 GB of training data: Binning 0.095 GB of training data: 4.045 s
# Binning 0.011 GB of validation data: 4.087 s
# Binning 0.011 GB of validation data: 4.184 s
# Binning 0.011 GB of validation data: 0.088 s
# Fitting gradient boosted rounds:
# 4.200 s
# Binning 0.011 GB of validation data: 0.277 s
# Fitting gradient boosted rounds:
# 0.255 s
# Fitting gradient boosted rounds:
# 0.152 s
# 4.564 s
# Binning 0.011 GB of validation data: Fitting gradient boosted rounds:
# 0.128 s
# Fitting gradient boosted rounds:
# Fit 24 trees in 18.595 s, (744 total leaves)
# Time spent computing histograms: 8.550s
# Time spent finding best splits:  0.273s
# Time spent applying splits:      0.968s
# Time spent predicting:           0.160s
# Fit 23 trees in 19.033 s, (713 total leaves)
# Time spent computing histograms: 9.092s
# Time spent finding best splits:  0.149s
# Time spent applying splits:      0.832s
# Time spent predicting:           0.247s
# Fit 24 trees in 19.541 s, (744 total leaves)
# Time spent computing histograms: 9.418s
# Time spent finding best splits:  0.149s
# Time spent applying splits:      1.103s
# Time spent predicting:           0.146s
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# Iteration 12, loss = 0.18379751
# Validation score: 0.949892
# Iteration 12, loss = 0.18378305
# Validation score: 0.949747
# Iteration 13, loss = 0.18348614
# Iteration 13, loss = 0.18334526
# Validation score: 0.949921
# Validation score: 0.950007
# Iteration 13, loss = 0.18330943
# Iteration 13, loss = 0.18360839
# Validation score: 0.949776
# Validation score: 0.949718
# Iteration 14, loss = 0.18309598
# Iteration 14, loss = 0.18320070
# Validation score: 0.949892
# Validation score: 0.949892
# Iteration 14, loss = 0.18296707
# Iteration 14, loss = 0.18307709
# Validation score: 0.949805
# Validation score: 0.949805
# Iteration 15, loss = 0.18271646
# Validation score: 0.949949
# Iteration 15, loss = 0.18274851
# Validation score: 0.949805
# Iteration 15, loss = 0.18292420
# Validation score: 0.949430
# Iteration 15, loss = 0.18270027
# Validation score: 0.949661
# Iteration 16, loss = 0.18244413
# Validation score: 0.949718
# Iteration 16, loss = 0.18252292
# Iteration 16, loss = 0.18255636
# Iteration 16, loss = 0.18233568
# Validation score: 0.949863
# Validation score: 0.949834
# Validation score: 0.949892
# Iteration 17, loss = 0.18198098
# Validation score: 0.949892
# Iteration 17, loss = 0.18205800
# Iteration 17, loss = 0.18199210
# Validation score: 0.949343
# Validation score: 0.949603
# Iteration 17, loss = 0.18207243
# Validation score: 0.949921
# Iteration 18, loss = 0.18168533
# Validation score: 0.949978
# Iteration 18, loss = 0.18176231
# Iteration 18, loss = 0.18160377
# Validation score: 0.949227
# Validation score: 0.949747
# Iteration 18, loss = 0.18174053
# Validation score: 0.949921
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.3min remaining:  3.5min
# Iteration 19, loss = 0.18100335
# Validation score: 0.949892
# Iteration 19, loss = 0.18134765
# Validation score: 0.949545
# Iteration 19, loss = 0.18116113
# Validation score: 0.950007
# Iteration 20, loss = 0.18093737
# Validation score: 0.949921
# Iteration 20, loss = 0.18091667
# Validation score: 0.949690
# Iteration 20, loss = 0.18068036
# Validation score: 0.949834
# Iteration 21, loss = 0.18053204
# Validation score: 0.949978
# Iteration 21, loss = 0.18088370
# Validation score: 0.949718
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# Iteration 21, loss = 0.18056606
# Validation score: 0.949863
# Iteration 22, loss = 0.18007935
# Validation score: 0.949776
# Iteration 22, loss = 0.18036414
# Validation score: 0.949834
# Iteration 23, loss = 0.17986057
# Validation score: 0.949834
# Iteration 23, loss = 0.17984552
# Validation score: 0.949545
# Iteration 24, loss = 0.17935842
# Validation score: 0.949690
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# Iteration 24, loss = 0.17948803
# Validation score: 0.949690
# Iteration 25, loss = 0.17909782
# Validation score: 0.949516
# Iteration 26, loss = 0.17879573
# Validation score: 0.949718
# Iteration 27, loss = 0.17810493
# Validation score: 0.949776
# Iteration 28, loss = 0.17804194
# Validation score: 0.949574
# Iteration 29, loss = 0.17749647
# Validation score: 0.949083
# Iteration 30, loss = 0.17707914
# Validation score: 0.949574
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  3.1min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  9.7min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  9.8min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    3.3s finished
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  9.8min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  9.8min finished
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.8s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  9.8min remaining: 14.8min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.5s finished
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.4s finished
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  9.9min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    1.9s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  9.9min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.9s finished
# 0.9494658238142767

# %%
y_val_pred = clf.predict(x_val)
confusion_matrix(y_val,y_val_pred)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.5s finished
# array([[102714,     50],
#        [  5418,     22]])

# %%
clf.score(x_val,y_val)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.5s finished
# 0.9494658238142767

# %%
precision_score(y_val,y_val_pred)
# Out:
# 0.3055555555555556

# %%
recall_score(y_val,y_val_pred)
# Out:
# 0.004044117647058824
