# %% [markdown]
# # Compromises:
# ## Neural Network:
# - Can't do log-linking
# - ELU not supported

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import StackingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import train_test_split

from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.metrics import r2_score, accuracy_score, recall_score,precision_score, confusion_matrix

import pandas as pd
import numpy as np

# %%
# df = pd.read_csv(r"data\claims_train_scaled.csv")
df = pd.read_csv(r"../../data/claims_train_scaled.csv")
# df.drop("Area",axis=1,inplace=True)
# fuel_map = {'Regular': 0, 'Diesel': 1}
# df['VehGas'] = df['VehGas'].map(fuel_map)
# x = df.drop(columns=["ClaimNb","Region","VehBrand","VehGas"])
x = df.drop(columns=["ClaimNb"])
x = pd.get_dummies(x, columns=['Region','VehGas','VehBrand'], drop_first=True, dtype=float)

y = (df["ClaimNb"] > 0).astype(int)

x_train, x_val, y_train, y_val = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
estimators = [
    ('rf', RandomForestClassifier(random_state=42, criterion='log_loss', verbose=1, oob_score=False, n_estimators=200, min_samples_split=2, min_samples_leaf=1, max_features=None, max_depth=20, bootstrap=False)),
    ('svr', make_pipeline(StandardScaler(),
                          LinearSVC(random_state=42, tol=1e-06, penalty='l2', loss='squared_hinge', C=0.75))),
    ('mlp', MLPClassifier(hidden_layer_sizes=(192,192,192), random_state=42, max_iter=30, batch_size=1000,learning_rate_init=0.001,activation='relu',verbose=True, early_stopping=True, tol=1e-6)),
    ('gbr', HistGradientBoostingClassifier(
                max_iter=1000,
                learning_rate=0.46, 
                max_depth=7,
                verbose=1,
                # categorical_features=["Region","VehBrand","VehGas"],
            )),
]

clf = StackingClassifier(
    estimators=estimators, final_estimator=LogisticRegression(), verbose=2, n_jobs=-1
)

clf.fit(x_train, y_train).score(x_val, y_val)
# Out:
# Binning 0.118 GB of training data: 0.741 s
# Binning 0.013 GB of validation data: 0.066 s
# Fitting gradient boosted rounds:
# Fit 30 trees in 4.718 s, (930 total leaves)
# Time spent computing histograms: 2.547s
# Time spent finding best splits:  0.015s
# Time spent applying splits:      0.189s
# Time spent predicting:           0.013s
# Iteration 1, loss = 0.19936862
# Validation score: 0.949864
# Iteration 2, loss = 0.19022697
# Validation score: 0.949864
# Iteration 3, loss = 0.18864485
# Validation score: 0.949864
# Iteration 4, loss = 0.18758815
# Validation score: 0.949817
# Iteration 5, loss = 0.18661937
# Validation score: 0.949817
# Iteration 6, loss = 0.18583152
# Validation score: 0.949817
# Iteration 7, loss = 0.18534672
# Validation score: 0.949864
# Iteration 8, loss = 0.18476862
# Validation score: 0.949794
# Iteration 9, loss = 0.18427755
# Validation score: 0.949540
# Iteration 10, loss = 0.18391238
# Validation score: 0.949610
# Iteration 11, loss = 0.18336158
# Validation score: 0.949864
# Iteration 12, loss = 0.18281224
# Validation score: 0.949540
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  7.0min finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# Binning 0.095 GB of training data: Binning 0.095 GB of training data: Binning 0.095 GB of training data: Binning 0.095 GB of training data: Binning 0.095 GB of training data: 3.211 s
# Binning 0.011 GB of validation data: 0.275 s
# 3.513 s
# Binning 0.011 GB of validation data: 3.773 s
# Binning 0.011 GB of validation data: Fitting gradient boosted rounds:
# 3.719 s
# Binning 0.011 GB of validation data: 0.220 s
# Fitting gradient boosted rounds:
# 0.304 s
# 3.799 s
# Binning 0.011 GB of validation data: Fitting gradient boosted rounds:
# 0.210 s
# Fitting gradient boosted rounds:
# 0.182 s
# Fitting gradient boosted rounds:
# Fit 18 trees in 16.447 s, (558 total leaves)
# Time spent computing histograms: 7.481s
# Time spent finding best splits:  0.131s
# Time spent applying splits:      0.692s
# Time spent predicting:           0.236s
# Fit 19 trees in 16.675 s, (589 total leaves)
# Time spent computing histograms: 7.959s
# Time spent finding best splits:  0.095s
# Time spent applying splits:      0.567s
# Time spent predicting:           0.134s
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   17.8s remaining:   26.7s
# Fit 21 trees in 17.799 s, (651 total leaves)
# Time spent computing histograms: 9.003s
# Time spent finding best splits:  0.073s
# Time spent applying splits:      0.953s
# Time spent predicting:           0.113s
# Fit 23 trees in 18.771 s, (713 total leaves)
# Time spent computing histograms: 9.410s
# Time spent finding best splits:  0.202s
# Time spent applying splits:      1.114s
# Time spent predicting:           0.120s
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   20.4s remaining:   30.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   20.5s finished
# Fit 33 trees in 20.319 s, (1023 total leaves)
# Time spent computing histograms: 10.762s
# Time spent finding best splits:  0.292s
# Time spent applying splits:      1.130s
# Time spent predicting:           0.174s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   20.8s finished
# Iteration 1, loss = 0.20161533
# Iteration 1, loss = 0.20159697
# Iteration 1, loss = 0.20171513
# Iteration 1, loss = 0.20150429
# Iteration 1, loss = 0.20169758
# Validation score: 0.949863
# Validation score: 0.949863
# Validation score: 0.949863
# Validation score: 0.949863
# Validation score: 0.949863
# Iteration 2, loss = 0.19062841
# Iteration 2, loss = 0.19111582
# Iteration 2, loss = 0.19083995
# Validation score: 0.949863
# Iteration 2, loss = 0.19064424
# Iteration 2, loss = 0.19063715
# Validation score: 0.949863
# Validation score: 0.949863
# Validation score: 0.949863
# Validation score: 0.949863
# Iteration 3, loss = 0.18929621
# Iteration 3, loss = 0.18923038
# Validation score: 0.949834
# Iteration 3, loss = 0.18867797
# Validation score: 0.949863
# Iteration 3, loss = 0.18905459
# Validation score: 0.949863
# Validation score: 0.949863
# Iteration 3, loss = 0.18910580
# Validation score: 0.949834
# Iteration 4, loss = 0.18808632
# Iteration 4, loss = 0.18790586
# Validation score: 0.949863
# Iteration 4, loss = 0.18755311
# Iteration 4, loss = 0.18781845
# Validation score: 0.949863
# Validation score: 0.949776
# Validation score: 0.949834
# Iteration 4, loss = 0.18779200
# Validation score: 0.949892
# Iteration 5, loss = 0.18713275
# Iteration 5, loss = 0.18685401
# Iteration 5, loss = 0.18669546
# Validation score: 0.949863
# Iteration 5, loss = 0.18681094
# Validation score: 0.949776
# Validation score: 0.949834
# Validation score: 0.949776
# Iteration 5, loss = 0.18682795
# Validation score: 0.949863
# Iteration 6, loss = 0.18641576
# Iteration 6, loss = 0.18622381
# Validation score: 0.949863
# Iteration 6, loss = 0.18617211
# Iteration 6, loss = 0.18617430
# Validation score: 0.949718
# Validation score: 0.949776
# Iteration 6, loss = 0.18611032
# Validation score: 0.949805
# Validation score: 0.949834
# Iteration 7, loss = 0.18542478
# Iteration 7, loss = 0.18526089
# Validation score: 0.949834
# Iteration 7, loss = 0.18534608
# Validation score: 0.949747
# Iteration 7, loss = 0.18523392
# Iteration 7, loss = 0.18535935
# Validation score: 0.949834
# Validation score: 0.949776
# Validation score: 0.949863
# Iteration 8, loss = 0.18482898
# Iteration 8, loss = 0.18484765
# Iteration 8, loss = 0.18484141
# Validation score: 0.949776
# Iteration 8, loss = 0.18466877
# Validation score: 0.949776
# Validation score: 0.949805
# Iteration 8, loss = 0.18477312
# Validation score: 0.949892
# Validation score: 0.949805
# Iteration 9, loss = 0.18432992
# Iteration 9, loss = 0.18435887
# Iteration 9, loss = 0.18429165
# Validation score: 0.949747
# Iteration 9, loss = 0.18411653
# Validation score: 0.949863
# Iteration 9, loss = 0.18419521
# Validation score: 0.949834
# Validation score: 0.949834
# Validation score: 0.949747
# Iteration 10, loss = 0.18373326
# Iteration 10, loss = 0.18372105
# Validation score: 0.949776
# Iteration 10, loss = 0.18334831
# Iteration 10, loss = 0.18361706
# Iteration 10, loss = 0.18370192
# Validation score: 0.949805
# Validation score: 0.949718
# Validation score: 0.949776
# Validation score: 0.949863
# Iteration 11, loss = 0.18323107
# Iteration 11, loss = 0.18311548
# Validation score: 0.949834
# Validation score: 0.949805
# Iteration 11, loss = 0.18313764
# Iteration 11, loss = 0.18319131
# Iteration 11, loss = 0.18283513
# Validation score: 0.949632
# Validation score: 0.949603
# Validation score: 0.949892
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  3.2min
# Iteration 12, loss = 0.18275432
# Validation score: 0.949805
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# Iteration 12, loss = 0.18289195
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:  3.2min
# Iteration 12, loss = 0.18240471
# Validation score: 0.949892
# Iteration 12, loss = 0.18235201
# Iteration 12, loss = 0.18234375
# Validation score: 0.949747
# Validation score: 0.949690
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# Validation score: 0.949776
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  3.2min remaining:  4.8min
# Iteration 13, loss = 0.18233805
# Iteration 13, loss = 0.18186912
# Validation score: 0.949661
# Validation score: 0.949516
# Iteration 14, loss = 0.18175552
# Validation score: 0.949661
# Iteration 14, loss = 0.18127923
# Validation score: 0.949834
# Iteration 15, loss = 0.18094128
# Validation score: 0.949545
# Iteration 15, loss = 0.18024697
# Validation score: 0.949690
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# Iteration 16, loss = 0.18027324
# Validation score: 0.949863
# Iteration 17, loss = 0.17935207
# Validation score: 0.949805
# Iteration 18, loss = 0.17858202
# Validation score: 0.949747
# Iteration 19, loss = 0.17807091
# Validation score: 0.949603
# Iteration 20, loss = 0.17706716
# Validation score: 0.949458
# Iteration 21, loss = 0.17638797
# Validation score: 0.949632
# Iteration 22, loss = 0.17525288
# Validation score: 0.949458
# Iteration 23, loss = 0.17419768
# Validation score: 0.949112
# Validation score did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  4.7min finished
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  9.9min finished
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  9.9min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  9.9min finished
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    3.2s finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  9.9min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.8s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 10.0min remaining: 14.9min
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.7s finished
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.4s finished
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed: 10.0min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    1.9s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 10.0min finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.8s finished
# 0.9491146353184725

# %%
y_val_pred = clf.predict(x_val)
confusion_matrix(y_val,y_val_pred)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.7s finished
# array([[102651,    113],
#        [  5393,     47]])

# %%
clf.score(x_val,y_val)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    2.5s finished
# 0.9491146353184725

# %%
precision_score(y_val,y_val_pred)
# Out:
# 0.29375

# %%
recall_score(y_val,y_val_pred)
# Out:
# 0.008639705882352942
