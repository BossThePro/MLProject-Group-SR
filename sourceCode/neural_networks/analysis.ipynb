# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

df = pd.read_csv("results/results_library_test.csv")
df.describe()
# df[df["ClaimNb"] == 0].describe()
# df[df["ClaimNb"] == 1].describe()
# df[df["ClaimNb"] == 2].describe()
# df[df["ClaimNb"] == 3].describe()
# Out:
#             ClaimNb     Predicted
# count  54102.000000  54102.000000
# mean       0.052956      0.051835
# std        0.236472      0.047592
# min        0.000000      0.000772
# 25%        0.000000      0.023343
# 50%        0.000000      0.041916
# 75%        0.000000      0.063859
# max        3.000000      0.682730

# %%
import sklearn.metrics

y_true = np.array(df.loc[:,"ClaimNb"])
y_pred = np.array(df.loc[:,"Predicted"])

print(y_true)
print(y_pred)

print(sklearn.metrics.mean_poisson_deviance(y_true,y_pred))
print(sklearn.metrics.r2_score(y_true, y_pred))
print(sklearn.metrics.d2_tweedie_score(y_true, y_pred,power=1))
# Out:
# [0. 0. 0. ... 0. 0. 0.]
# [0.08365843 0.02294473 0.02271739 ... 0.04288729 0.02086311 0.04342569]
# 0.29474538322082666
# 0.029807615648843155
# 0.07594645042701764
