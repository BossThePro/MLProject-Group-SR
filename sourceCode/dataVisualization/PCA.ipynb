# %% [markdown]
# # Here we work with all the PCA + Clustering methods to visualise our data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df_scaled = pd.read_csv(r"data/claims_train_scaled.csv")
df_scaled.head()
# Out:
#    ClaimNb  Exposure Area  VehPower    VehAge   DrivAge  BonusMalus VehBrand  \
# 0        0      0.43    D  0.266880  1.974647 -0.672262    2.259081       B1
# 1        0      0.10    D  0.266880  1.794735  2.445658    2.259081       B2
# 2        0      0.33    E  0.266880 -0.724035 -0.672262    1.041179       B6
# 3        0      0.56    A -0.708699 -0.544123  1.949625   -0.497224      B13
# 4        0      0.27    E  0.754669 -1.263772 -0.601401   -0.625424      B11
#
#     VehGas   Density Region
# 0  Regular -0.187042    R24
# 1  Regular -0.302036    R25
# 2  Regular  0.599254    R82
# 3   Diesel -0.449057    R24
# 4   Diesel  0.308995    R53

# %%
df_scaled.drop(columns=["Area","VehBrand","VehGas","Region","ClaimNb", "Exposure"],inplace=True)
df_scaled
# Out:
#         VehPower    VehAge   DrivAge  BonusMalus   Density
# 0       0.266880  1.974647 -0.672262    2.259081 -0.187042
# 1       0.266880  1.794735  2.445658    2.259081 -0.302036
# 2       0.266880 -0.724035 -0.672262    1.041179  0.599254
# 3      -0.708699 -0.544123  1.949625   -0.497224 -0.449057
# 4       0.754669 -1.263772 -0.601401   -0.625424  0.308995
# ...          ...       ...       ...         ...       ...
# 541011 -0.220910  0.535350 -0.955710    1.041179 -0.121476
# 541012  1.730248  1.254998 -0.813986    0.015577 -0.280097
# 541013 -0.220910  0.175526 -0.955710    2.259081 -0.391812
# 541014  1.242458 -0.004387 -0.459677    0.784778  0.379606
# 541015  0.266880  1.974647 -0.317953    2.964182 -0.446283
#
# [541016 rows x 5 columns]

# %%
pca_claims = PCA()
pca_claims.fit(df_scaled)
scores = pca_claims.transform(df_scaled)

# %%
df_pca = pd.DataFrame(scores)

# %%
#pd.plotting.scatter_matrix(df_pca)
# Out:
# array([[<Axes: xlabel='0', ylabel='0'>, <Axes: xlabel='1', ylabel='0'>,
#         <Axes: xlabel='2', ylabel='0'>, <Axes: xlabel='3', ylabel='0'>,
#         <Axes: xlabel='4', ylabel='0'>, <Axes: xlabel='5', ylabel='0'>],
#        [<Axes: xlabel='0', ylabel='1'>, <Axes: xlabel='1', ylabel='1'>,
#         <Axes: xlabel='2', ylabel='1'>, <Axes: xlabel='3', ylabel='1'>,
#         <Axes: xlabel='4', ylabel='1'>, <Axes: xlabel='5', ylabel='1'>],
#        [<Axes: xlabel='0', ylabel='2'>, <Axes: xlabel='1', ylabel='2'>,
#         <Axes: xlabel='2', ylabel='2'>, <Axes: xlabel='3', ylabel='2'>,
#         <Axes: xlabel='4', ylabel='2'>, <Axes: xlabel='5', ylabel='2'>],
#        [<Axes: xlabel='0', ylabel='3'>, <Axes: xlabel='1', ylabel='3'>,
#         <Axes: xlabel='2', ylabel='3'>, <Axes: xlabel='3', ylabel='3'>,
#         <Axes: xlabel='4', ylabel='3'>, <Axes: xlabel='5', ylabel='3'>],
#        [<Axes: xlabel='0', ylabel='4'>, <Axes: xlabel='1', ylabel='4'>,
#         <Axes: xlabel='2', ylabel='4'>, <Axes: xlabel='3', ylabel='4'>,
#         <Axes: xlabel='4', ylabel='4'>, <Axes: xlabel='5', ylabel='4'>],
#        [<Axes: xlabel='0', ylabel='5'>, <Axes: xlabel='1', ylabel='5'>,
#         <Axes: xlabel='2', ylabel='5'>, <Axes: xlabel='3', ylabel='5'>,
#         <Axes: xlabel='4', ylabel='5'>, <Axes: xlabel='5', ylabel='5'>]],
#       dtype=object)

# %%
import seaborn as sns
df_original = pd.read_csv("data/claims_train_scaled.csv")
df_original["HasClaim"] = (df_original["ClaimNb"] >= 1)
df_original = df_original["HasClaim"]
df = df_pca.join(df_original)
df
# Out:
#                0         1         2         3         4  HasClaim
# 0       2.331210 -1.003365  1.134500  0.808672  1.085589     False
# 1       0.172043 -1.112278  0.846270  1.399246  3.244593     False
# 2       1.053874  1.080560 -0.021228 -0.375640  0.265953     False
# 3      -1.701204 -0.333740 -1.007483  0.078143  1.010763     False
# 4      -0.335504  1.159624  0.177664 -0.967323 -0.768368     False
# ...          ...       ...       ...       ...       ...       ...
# 541011  1.490910 -0.332294  0.094973  0.047328  0.055666     False
# 541012  0.532603 -0.446974  2.149852 -0.090314 -0.443371     False
# 541013  2.253625 -0.202646 -0.062868 -0.417734  0.975503     False
# 541014  0.711586  0.721911  1.150432 -0.278393  0.294099     False
# 541015  2.562439 -1.144318  1.108128  0.696644  1.862331     False
#
# [541016 rows x 6 columns]

# %%
sns.pairplot(df,hue="HasClaim",palette={True: 'red', False: 'blue'})

# %%
#the original dataset
df_original = pd.read_csv("data\claims_train_final.csv")
df_original.drop(columns=["Area","VehBrand","VehGas","Region"],inplace=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\c'
# <>:2: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\khatt\AppData\Local\Temp\ipykernel_26796\1396806940.py:2: SyntaxWarning: invalid escape sequence '\c'
#   df_original = pd.read_csv("data\claims_train_final.csv")

# %%
df_original.head()
# Out:
#    ClaimNb  Exposure  VehPower  VehAge  DrivAge  BonusMalus  Density
# 0        0      0.43         7      18       36          95     1054
# 1        0      0.10         7      17       80          95      598
# 2        0      0.33         7       3       36          76     4172
# 3        0      0.56         5       4       73          52       15
# 4        0      0.27         8       0       37          50     3021

# %%
#making a biplot
i, j = 0, 1 # which components 
colors = np.where(df_original['ClaimNb'] == 0, 'green', 'red')
fig, ax = plt.subplots(1, 1, figsize=(10, 10)) 
ax.scatter(scores[:,0], scores[:,1],c=colors,alpha=0.5) 
ax.set_xlabel('PC%d' % (i+1)) 
ax.set_ylabel('PC%d' % (j+1)) 
for k in range(pca_claims.components_.shape[1]):
    ax.arrow(0, 0, pca_claims.components_[i,k], pca_claims.components_[j,k]) 
    ax.text(pca_claims.components_[i,k], pca_claims.components_[j,k], df_original.columns[k])
